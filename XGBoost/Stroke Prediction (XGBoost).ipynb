# %%
#install extreme gradient boost package
# !pip install xgboost
# Out:
# Collecting xgboost
#   Using cached xgboost-1.6.1-py3-none-manylinux2014_x86_64.whl (192.9 MB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from xgboost) (1.22.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.8/site-packages (from xgboost) (1.8.0)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.6.1

# %%
#install imbalanced learning package
# !pip install -U imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Using cached imbalanced_learn-0.9.1-py3-none-any.whl (199 kB)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from imbalanced-learn) (3.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from imbalanced-learn) (1.1.0)
# Collecting scikit-learn>=1.1.0
#   Using cached scikit_learn-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.2 MB)
# Requirement already satisfied, skipping upgrade: numpy>=1.17.3 in /opt/conda/lib/python3.8/site-packages (from imbalanced-learn) (1.22.3)
# Requirement already satisfied, skipping upgrade: scipy>=1.3.2 in /opt/conda/lib/python3.8/site-packages (from imbalanced-learn) (1.8.0)
# Installing collected packages: scikit-learn, imbalanced-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# Successfully installed imbalanced-learn-0.9.1 scikit-learn-1.1.1

# %%
#import the necessary libraries
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE

# %%
#load csv file into a dataframe & preview the dataframe
df = pd.read_csv('Stroke.csv')
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
#check the number of null values in the dataset
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
#drop all the rows with null values
df.dropna(axis=0,inplace=True)
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# 5           Private          Urban             186.21  29.0  formerly smoked
# ...             ...            ...                ...   ...              ...
# 5104       children          Rural             103.08  18.6          Unknown
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 2          1
# 3          1
# 4          1
# 5          1
# ...      ...
# 5104       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [4909 rows x 12 columns]

# %%
#check data types of features
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
#convert float data type to integer data type for certain features
df['age'] = df['age'].astype(int)
df['bmi'] = df['bmi'].astype(int)
df['avg_glucose_level'] = df['avg_glucose_level'].astype(int)

# %%
#check if data type changes carried through
df.dtypes
# Out:
# id                    int64
# gender               object
# age                   int64
# hypertension          int64
# heart_disease         int64
# ever_married         object
# work_type            object
# Residence_type       object
# avg_glucose_level     int64
# bmi                   int64
# smoking_status       object
# stroke                int64
# dtype: object

# %%
#profile the data
for column in df:
    print(f'{column} : {df[column].unique()}')
# Out:
# id : [ 9046 31112 60182 ... 19723 37544 44679]
# gender : ['Male' 'Female' 'Other']
# age : [67 80 49 79 81 74 69 78 61 54 50 64 75 60 71 52 82 65 57 42 48 72 58 76
#  39 77 63 73 56 45 70 59 66 43 68 47 53 38 55 46 32 51 14  3  8 37 40 35
#  20 44 25 27 23 17 13  4 16 22 30 29 11 21 18 33 24 36  0 34 41  5 26 31
#   7 12 62  2  9 15 28 10  1 19  6]
# hypertension : [0 1]
# heart_disease : [1 0]
# ever_married : ['Yes' 'No']
# work_type : ['Private' 'Self-employed' 'Govt_job' 'children' 'Never_worked']
# Residence_type : ['Urban' 'Rural']
# avg_glucose_level : [228 105 171 174 186  70  94  58  80 120 104 214 167 191 221  89 193 233
#  208 102 100 195 212  83 196 252  84 219  74  92  60  78  71 144 213 243
#  107  99 127 124  59 194 180 185  61  93 113  86  72 179 116  96  66 240
#  110 143  88  79 111  98 226  68  64 235  76  82 190 231  73 129 224 216
#   62 259 249 131 200 130 182 206 263 140 207 199 103 151  67 239 223  77
#  203 133 162  91  97  56 112 137 215 205 118 271 242 175  90 109  87 106
#  134  95 210 250 184  81 218 211 197 247  57  69 161  85  75 198  55 149
#  117 114 141 146 220 115 234 229 138 101 136 126  63 251 123 122 178 147
#  139 225 227 145 201 170 217 132  65 183 108 155 189 163 188 204 125 158
#  148 156 121 119 222 128 173 152 254 160 135 237 236 142 232 157 165 246
#  153 230 267 150 181 169 244 154 253 238 168 202 176 187 209 164 192 266
#  172 255 159 248 261 256 166 177]
# bmi : [36 32 34 24 29 27 22 28 30 37 25 48 26 23 44 33 20 38 39 31 40 47 21 45
#  41 19 56 35 46 42 16 18 17 50 54 60 43 64 15 13 49 51 71 12 55 14 57 52
#  78 53 66 10 97 11 63 61 58 59 92]
# smoking_status : ['formerly smoked' 'never smoked' 'smokes' 'Unknown']
# stroke : [1 0]

# %%
#drop irrelevant features
df.drop('id',axis=1,inplace=True)
df
# Out:
#       gender  age  hypertension  heart_disease ever_married      work_type  \
# 0       Male   67             0              1          Yes        Private
# 2       Male   80             0              1          Yes        Private
# 3     Female   49             0              0          Yes        Private
# 4     Female   79             1              0          Yes  Self-employed
# 5       Male   81             0              0          Yes        Private
# ...      ...  ...           ...            ...          ...            ...
# 5104  Female   13             0              0           No       children
# 5106  Female   81             0              0          Yes  Self-employed
# 5107  Female   35             0              0          Yes  Self-employed
# 5108    Male   51             0              0          Yes        Private
# 5109  Female   44             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level  bmi   smoking_status  stroke
# 0             Urban                228   36  formerly smoked       1
# 2             Rural                105   32     never smoked       1
# 3             Urban                171   34           smokes       1
# 4             Rural                174   24     never smoked       1
# 5             Urban                186   29  formerly smoked       1
# ...             ...                ...  ...              ...     ...
# 5104          Rural                103   18          Unknown       0
# 5106          Urban                125   40     never smoked       0
# 5107          Rural                 82   30     never smoked       0
# 5108          Rural                166   25  formerly smoked       0
# 5109          Urban                 85   26          Unknown       0
#
# [4909 rows x 11 columns]

# %%
#convert categorical data into numerical
hot_data = pd.get_dummies(df)
hot_data
# Out:
#       age  hypertension  heart_disease  avg_glucose_level  bmi  stroke  \
# 0      67             0              1                228   36       1
# 2      80             0              1                105   32       1
# 3      49             0              0                171   34       1
# 4      79             1              0                174   24       1
# 5      81             0              0                186   29       1
# ...   ...           ...            ...                ...  ...     ...
# 5104   13             0              0                103   18       0
# 5106   81             0              0                125   40       0
# 5107   35             0              0                 82   30       0
# 5108   51             0              0                166   25       0
# 5109   44             0              0                 85   26       0
#
#       gender_Female  gender_Male  gender_Other  ever_married_No  ...  \
# 0                 0            1             0                0  ...
# 2                 0            1             0                0  ...
# 3                 1            0             0                0  ...
# 4                 1            0             0                0  ...
# 5                 0            1             0                0  ...
# ...             ...          ...           ...              ...  ...
# 5104              1            0             0                1  ...
# 5106              1            0             0                0  ...
# 5107              1            0             0                0  ...
# 5108              0            1             0                0  ...
# 5109              1            0             0                0  ...
#
#       work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                          0                  1                        0
# 2                          0                  1                        0
# 3                          0                  1                        0
# 4                          0                  0                        1
# 5                          0                  1                        0
# ...                      ...                ...                      ...
# 5104                       0                  0                        0
# 5106                       0                  0                        1
# 5107                       0                  0                        1
# 5108                       0                  1                        0
# 5109                       0                  0                        0
#
#       work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 0                      0                     0                     1
# 2                      0                     1                     0
# 3                      0                     0                     1
# 4                      0                     1                     0
# 5                      0                     0                     1
# ...                  ...                   ...                   ...
# 5104                   1                     1                     0
# 5106                   0                     0                     1
# 5107                   0                     1                     0
# 5108                   0                     1                     0
# 5109                   0                     0                     1
#
#       smoking_status_Unknown  smoking_status_formerly smoked  \
# 0                          0                               1
# 2                          0                               0
# 3                          0                               0
# 4                          0                               0
# 5                          0                               1
# ...                      ...                             ...
# 5104                       1                               0
# 5106                       0                               0
# 5107                       0                               0
# 5108                       0                               1
# 5109                       1                               0
#
#       smoking_status_never smoked  smoking_status_smokes
# 0                               0                      0
# 2                               1                      0
# 3                               0                      1
# 4                               1                      0
# 5                               0                      0
# ...                           ...                    ...
# 5104                            0                      0
# 5106                            1                      0
# 5107                            1                      0
# 5108                            0                      0
# 5109                            0                      0
#
# [4909 rows x 22 columns]

# %%
#normalize the data to minimize the effects of large numbers
cols_to_scale = ['age','avg_glucose_level','bmi']

scaler = MinMaxScaler()

hot_data[cols_to_scale] = scaler.fit_transform(hot_data[cols_to_scale])
hot_data
# Out:
#            age  hypertension  heart_disease  avg_glucose_level       bmi  \
# 0     0.817073             0              1           0.800926  0.298851
# 2     0.975610             0              1           0.231481  0.252874
# 3     0.597561             0              0           0.537037  0.275862
# 4     0.963415             1              0           0.550926  0.160920
# 5     0.987805             0              0           0.606481  0.218391
# ...        ...           ...            ...                ...       ...
# 5104  0.158537             0              0           0.222222  0.091954
# 5106  0.987805             0              0           0.324074  0.344828
# 5107  0.426829             0              0           0.125000  0.229885
# 5108  0.621951             0              0           0.513889  0.172414
# 5109  0.536585             0              0           0.138889  0.183908
#
#       stroke  gender_Female  gender_Male  gender_Other  ever_married_No  ...  \
# 0          1              0            1             0                0  ...
# 2          1              0            1             0                0  ...
# 3          1              1            0             0                0  ...
# 4          1              1            0             0                0  ...
# 5          1              0            1             0                0  ...
# ...      ...            ...          ...           ...              ...  ...
# 5104       0              1            0             0                1  ...
# 5106       0              1            0             0                0  ...
# 5107       0              1            0             0                0  ...
# 5108       0              0            1             0                0  ...
# 5109       0              1            0             0                0  ...
#
#       work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                          0                  1                        0
# 2                          0                  1                        0
# 3                          0                  1                        0
# 4                          0                  0                        1
# 5                          0                  1                        0
# ...                      ...                ...                      ...
# 5104                       0                  0                        0
# 5106                       0                  0                        1
# 5107                       0                  0                        1
# 5108                       0                  1                        0
# 5109                       0                  0                        0
#
#       work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 0                      0                     0                     1
# 2                      0                     1                     0
# 3                      0                     0                     1
# 4                      0                     1                     0
# 5                      0                     0                     1
# ...                  ...                   ...                   ...
# 5104                   1                     1                     0
# 5106                   0                     0                     1
# 5107                   0                     1                     0
# 5108                   0                     1                     0
# 5109                   0                     0                     1
#
#       smoking_status_Unknown  smoking_status_formerly smoked  \
# 0                          0                               1
# 2                          0                               0
# 3                          0                               0
# 4                          0                               0
# 5                          0                               1
# ...                      ...                             ...
# 5104                       1                               0
# 5106                       0                               0
# 5107                       0                               0
# 5108                       0                               1
# 5109                       1                               0
#
#       smoking_status_never smoked  smoking_status_smokes
# 0                               0                      0
# 2                               1                      0
# 3                               0                      1
# 4                               1                      0
# 5                               0                      0
# ...                           ...                    ...
# 5104                            0                      0
# 5106                            1                      0
# 5107                            1                      0
# 5108                            0                      0
# 5109                            0                      0
#
# [4909 rows x 22 columns]

# %%
#check to see if  the dataset is balanced
df['stroke'].value_counts()
# Out:
# 0    4700
# 1     209
# Name: stroke, dtype: int64

# %%
#split dependent variables from independent
X = hot_data.drop('stroke',axis=1)
y = hot_data['stroke']

# %%
#balance the dataset using over-sampling method to create data for under-sampled
smote = SMOTE(sampling_strategy='minority')
features, target = smote.fit_resample(X,y)

target.value_counts()
# Out:
# 1    4700
# 0    4700
# Name: stroke, dtype: int64

# %%
#split the dataset into training and testing (80/20)
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2)

# %%
#convert training and testing data into sets for xgb purposes
training_data = xgb.DMatrix(X_train, label=y_train)
testing_data = xgb.DMatrix(X_test, label=y_test)

# %%
#specify xgb model parameters
param = {
    'booster': 'gbtree',
    'max_depth': 3,
    'eta': 0.3,
    'objective': 'multi:softmax',
    'num_class': 2
}
epochs = 10

# %%
#train the model
model = xgb.train(param,training_data,epochs)

# %%
#get predictions using the model
predictions = model.predict(testing_data)

# %%
#score the model
accuracy_score(y_test,predictions)
# Out:
# 0.8531914893617021
